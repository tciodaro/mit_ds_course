# %% [markdown]
# # Projeto Vinhos
# ## Analisando Dados

# %%
import pandas as pd
dados = pd.read_csv('Data/Processed/retail/bigTableWines.csv')

# %% [markdown]
# ## Verificação de dados faltantes

# %%
dadosFaltantes = dados.isnull()
print(dadosFaltantes.shape[0])
dadosFaltantes.head(10)
# Out:
# 6497
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       False          False             False        False           False
# 1       False          False             False        False           False
# 2       False          False             False        False           False
# 3       False          False             False        False           False
# 4       False          False             False        False           False
# 5       False          False             False        False           False
# 6       False          False             False        False           False
# 7       False          False             False        False           False
# 8       False          False             False        False           False
# 9       False          False             False        False           False
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# 0      False                False                 False    False  False
# 1      False                False                 False    False  False
# 2      False                False                 False    False  False
# 3      False                False                 False    False  False
# 4      False                False                 False    False  False
# 5      False                False                 False    False  False
# 6      False                False                 False    False  False
# 7      False                False                 False    False  False
# 8      False                False                 False    False  False
# 9      False                False                 False    False  False
#
#    sulphates  alcohol  quality  Tipo Vinho
# 0      False    False    False       False
# 1      False    False    False       False
# 2      False    False    False       False
# 3      False    False    False       False
# 4      False    False    False       False
# 5      False    False    False       False
# 6      False    False    False       False
# 7      False    False    False       False
# 8      False    False    False       False
# 9      False    False    False       False

# %%
dados.describe().round(2)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        6497.00           6497.00      6497.00         6497.00
# mean            7.22              0.34         0.32            5.44
# std             1.30              0.16         0.15            4.76
# min             3.80              0.08         0.00            0.60
# 25%             6.40              0.23         0.25            1.80
# 50%             7.00              0.29         0.31            3.00
# 75%             7.70              0.40         0.39            8.10
# max            15.90              1.58         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    6497.00              6497.00               6497.00  6497.00  6497.00
# mean        0.06                30.53                115.74     0.99     3.22
# std         0.04                17.75                 56.52     0.00     0.16
# min         0.01                 1.00                  6.00     0.99     2.72
# 25%         0.04                17.00                 77.00     0.99     3.11
# 50%         0.05                29.00                118.00     0.99     3.21
# 75%         0.06                41.00                156.00     1.00     3.32
# max         0.61               289.00                440.00     1.04     4.01
#
#        sulphates  alcohol  quality
# count    6497.00  6497.00  6497.00
# mean        0.53    10.49     5.82
# std         0.15     1.19     0.87
# min         0.22     8.00     3.00
# 25%         0.43     9.50     5.00
# 50%         0.51    10.30     6.00
# 75%         0.60    11.30     6.00
# max         2.00    14.90     9.00

# %%
(((dados.count(axis=0)/dados.shape[0])*100)-100).round(1)
# Out:
# fixed acidity           0.0
# volatile acidity        0.0
# citric acid             0.0
# residual sugar          0.0
# chlorides               0.0
# free sulfur dioxide     0.0
# total sulfur dioxide    0.0
# density                 0.0
# pH                      0.0
# sulphates               0.0
# alcohol                 0.0
# quality                 0.0
# Tipo Vinho              0.0
# dtype: float64

# %% [markdown]
# # Faixa Dinâmica de Cada Variável

# %%
dadosNumericos = dados.copy()
dadosNumericos.drop(['Tipo Vinho'], axis=1, inplace=True)
faixaDinamica = pd.concat([dadosNumericos.min(), dadosNumericos.max()], axis=1)
faixaDinamica.columns = ['Min', 'Max']
faixaDinamica['Range'] = faixaDinamica['Max'] - faixaDinamica['Min']
faixaDinamica
# Out:
#                           Min        Max      Range
# fixed acidity         3.80000   15.90000   12.10000
# volatile acidity      0.08000    1.58000    1.50000
# citric acid           0.00000    1.66000    1.66000
# residual sugar        0.60000   65.80000   65.20000
# chlorides             0.00900    0.61100    0.60200
# free sulfur dioxide   1.00000  289.00000  288.00000
# total sulfur dioxide  6.00000  440.00000  434.00000
# density               0.98711    1.03898    0.05187
# pH                    2.72000    4.01000    1.29000
# sulphates             0.22000    2.00000    1.78000
# alcohol               8.00000   14.90000    6.90000
# quality               3.00000    9.00000    6.00000

# %% [markdown]
# ## Histogramas com as distribuicoes das variaveis. Utilizar tambem KDE. Analisar padrões existentes

# %%
import matplotlib.pyplot as plt

for coluna in dados.columns:
    plt.figure(figsize=[5,3])
    plt.title(coluna)
    plt.hist(dados[coluna])

# %%
for coluna in dadosNumericos.columns:
    plt.figure(figsize=[4,4])
    plt.title(coluna)
    dadosNumericos[coluna].plot.kde()

# %% [markdown]
# ## Histogramas e KDE para diferentes grupos.

# %%
dadosSemQuality = dadosNumericos.copy()
dadosSemQuality.drop(['quality'], axis=1, inplace=True)

for coluna in dadosSemQuality.columns:
    plt.figure(figsize=[4,4])
    plt.title(coluna)
    dadosNumericos.groupby(['quality'])[coluna].plot.kde(legend=True)

# %% [markdown]
# ## Coeficientes de Correlação

# %%
plt.figure(figsize=[10,5])
dados.corr()['quality'].drop('quality').plot.bar()

# %% [markdown]
# ## Boxplot

# %%
for coluna in dados.drop(['Tipo Vinho'], axis=1).columns:
    plt.figure(figsize=[7,3])
    plt.title(coluna)
    plt.boxplot(dados[coluna])

# %% [markdown]
# ## Scatter Plot

# %%
plt.rc('figure', figsize=[20,20])
pd.plotting.scatter_matrix(dados)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a3f7b6250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3fc5e350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4016b650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a401a0e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40356690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40389e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a403cc6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a403ffed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40409a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4044b410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a404b5750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a404e9f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a4052c790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40560f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a405a17d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a405d5fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40617810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4064af90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4068c850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a406ccbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40703890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40740c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a407778d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a407b5c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a407ec910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4082bc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40863950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4089ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a408d7990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40915d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4094d9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4098bd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a409c3a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40a02d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40a35a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40a77dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a40aaca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40aebe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40b22ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40b61e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40b98b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40bd5e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40c0cb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40c4bed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40c82b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40cc3f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40cf9bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40d39f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a40d6dc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40dadf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40de2c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40e21fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40e58c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40e994d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40ecbcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40f0d510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40f41d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40f84550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40fb8d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a40ff7590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a4102dd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4106d5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a410a3dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a410e3610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41118e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41159650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4118de50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a411cf690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41201e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a412446d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41278ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a412b9710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a412edf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4132f750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41360f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a413a5790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a413d8f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4141c7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4144efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41490810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a414c5f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41504850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41543bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4157b890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a415b8c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a415f08d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4162fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41665910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a416a1c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a416da950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41717cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4174f990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4178dd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a417c79d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41805d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4183ca10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a41879d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a418b0a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a418eedd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41924a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41965e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4199aad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a419d9e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41a0fb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41a4fe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41a85b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41ac4ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41afbb90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a41b3bf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41b72bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41bb0f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41be6c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41c26f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41c5ac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41c9afd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41ccfc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41d124d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41d46cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41d86510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41dbbd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a41dfc550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41e30d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41e71590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41ea4d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41ee85d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41f1add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41f5b610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41f91e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a41fd0650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a42007e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a42047690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4207ae90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a420bd6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a420f1ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a42133710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a42166f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a421a8750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a421dcf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4221d790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a42251f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a422937d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a422c6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a42309810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a4233bf90>]],
#       dtype=object)

# %%
import seaborn as sns
sns.pairplot(dados)
