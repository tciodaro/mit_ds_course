# %% [markdown]
# # Projeto DIVINO
# ## Normalização por Min/Max

# %%
import pandas as pd
from ipynb.fs.full.data_analiser import *

# %% [markdown]
# #### Carregando dados

# %%
dados = pd.read_csv('../Data/Processed/wine/bigTableWines.csv', sep=";")
dadosNumericos = dados.drop('Tipo Vinho', axis=1)
variavelAlvo = 'quality'
dados.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.59         0.14             1.9      0.076
# 1            7.8              0.59         0.14             2.6      0.086
# 2            7.8              0.59         0.14             2.3      0.086
# 3            8.8              0.28         0.49             1.9      0.075
# 4            7.4              0.59         0.14             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.42       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.42       0.56
#
#    alcohol  quality Tipo Vinho
# 0      9.4      5.0        Red
# 1      9.8      5.0        Red
# 2      9.8      5.0        Red
# 3      9.8      6.0        Red
# 4      9.4      5.0        Red

# %% [markdown]
# #### Normalizando

# %%
normed_data = normalizarPorMinMax(dadosNumericos)

# %% [markdown]
# #### KDE e Histograma comparando dados originais e normalizados

# %%
exibirHistogramaComKdeParaCadaVariavel2('Dados Originais', dadosNumericos, 'Min/Max', normed_data)

# %% [markdown]
# ### Faixa Dinâmica de Cada Variável:

# %%
exibirFaixaDinamicaDasVariaveis(normed_data)
# Out:
#                       Min  Max  Range
# fixed acidity         0.0  1.0    1.0
# volatile acidity      0.0  1.0    1.0
# citric acid           0.0  1.0    1.0
# residual sugar        0.0  1.0    1.0
# chlorides             0.0  1.0    1.0
# free sulfur dioxide   0.0  1.0    1.0
# total sulfur dioxide  0.0  1.0    1.0
# density               0.0  1.0    1.0
# pH                    0.0  1.0    1.0
# sulphates             0.0  1.0    1.0
# alcohol               0.0  1.0    1.0
# quality               0.0  1.0    1.0

# %% [markdown]
# ### Histograma e KDE das Variáveis

# %%
exibirHistogramaComKdeParaCadaVariavel(normed_data)

# %% [markdown]
# ### Histogramas e KDE para diferentes grupos.

# %%
exibirHistogramaComKdeParaCadaVariavelComAgrupamento(variavelAlvo, normed_data)

# %% [markdown]
# ### Coeficientes de Correlação

# %%
exibirGraficoCoeficientesDeCorrelacao(variavelAlvo, normed_data)

# %% [markdown]
# ### Scatter Matrix

# %%
exibirScatterMatrix(normed_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a219cd790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22015ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22b1e710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21ccdf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2299e750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21ee9f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a228a8790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21a40f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a5bb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2170e4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a7f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a229baf90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22868850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22e9cbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22b45890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2295ac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a220808d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22900c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22ac0910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22fe2c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2320c950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2324acd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23280990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232bfd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a232f69d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23335d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2336ca10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a233aad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a233e0a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2341fdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23457a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23495e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a234cbad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2350ae50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23542b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23580e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a235b6b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a235f5ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2362bb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2366bf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236a0bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236e3f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23715c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21ab6710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a216fcad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fdc950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2296bed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2299b450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22b33d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21916210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21b38e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21951ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a219bda90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21952c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21bc3990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a224412d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21000810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22027490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21a313d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21c01750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a210ffe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a3ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21a73dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fb4610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a219fbe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21936650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2199dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22ecb690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21c13b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a216ad6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21b57ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a208d4710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20854f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a224ca750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22416f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2189a790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2174cf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a209fe7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a222ad690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20f3a810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20efaf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20ed7850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21791bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21826890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20c99c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20f8d8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20cf2c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20dff910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2233ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20c23950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20b99cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20bba990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20c45d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20c359d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20d68650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20e37a10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20acbd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20b1aa50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a209a0dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20e9ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20ca7e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20d3df90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20b42e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20db7b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22274e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a207f2b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20909ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20941b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2248ef10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22fb1bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22f60f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21aeec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f71f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21e90c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21c64fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21d70c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21dda4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cdeacd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ce2a510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ce5dd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a208b4550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20a4cd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20a8d590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a217cbd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a221335d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2230add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22395610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a223cce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a224f0650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22524e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22565690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2259ae90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a225db6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2260fed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22650710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22684f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a226c5750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a226f8f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2273b790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2276ef90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a227b37d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a227e4fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22826810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22859f90>]],
#       dtype=object)

# %% [markdown]
# ### Analise de outlier por box-plot

# %%
exibirBoxplotPorVariavel(normed_data)
