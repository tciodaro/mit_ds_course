# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

pandas.set_option("display.precision", 2)

input_table = '../mit_ds_course/Data/Processed/retail/bigtable_data.parquet'

# %% [markdown]
# # Load Time Series Data

# %%
data = pandas.read_parquet(input_table)
grain_cols = ['Store','Dept']
date_col = ['Date']
target_col = ['Weekly_Sales']
print('data shape:', data.shape)
print('data columns:', data.columns.tolist())

# mess with data
data['MarkDown1'] = np.nan


data.head()
# Out:
# data shape: (59000, 16)
# data columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment']
#   Store Dept       Date  Weekly_Sales  IsHoliday Type      Size  Temperature  \
# 0     1    1 2010-02-05      24924.50          0    A  151315.0        42.31
# 1     1    2 2010-02-05      50605.27          0    A  151315.0        42.31
# 2     1    3 2010-02-05      13740.12          0    A  151315.0        42.31
# 3     1    4 2010-02-05      39954.04          0    A  151315.0        42.31
# 4     1    5 2010-02-05      32229.38          0    A  151315.0        42.31
#
#    Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5    CPI  \
# 0        2.57        NaN        0.0        0.0        0.0        0.0  211.1
# 1        2.57        NaN        0.0        0.0        0.0        0.0  211.1
# 2        2.57        NaN        0.0        0.0        0.0        0.0  211.1
# 3        2.57        NaN        0.0        0.0        0.0        0.0  211.1
# 4        2.57        NaN        0.0        0.0        0.0        0.0  211.1
#
#    Unemployment
# 0          8.11
# 1          8.11
# 2          8.11
# 3          8.11
# 4          8.11

# %% [markdown]
# # Show Table With One Entire Variable Missing

# %%
data.describe()
# Out:
#        Weekly_Sales  IsHoliday       Size  Temperature  Fuel_Price  MarkDown1  \
# count      59000.00   59000.00   59000.00     59000.00    59000.00        0.0
# mean       19053.35       0.07  143311.99        68.02        3.22        NaN
# std        27478.29       0.26   73582.96        14.82        0.42        NaN
# min        -1098.00       0.00   34875.00        28.84        2.51        NaN
# 25%         2527.05       0.00   37392.00        56.99        2.76        NaN
# 50%         8138.18       0.00  202307.00        69.68        3.29        NaN
# 75%        23510.00       0.00  202505.00        81.02        3.59        NaN
# max       385051.04       1.00  205863.00        93.34        3.91        NaN
#
#        MarkDown2  MarkDown3  MarkDown4  MarkDown5       CPI  Unemployment
# count   59000.00   59000.00   59000.00   59000.00  59000.00      59000.00
# mean      972.90     496.37    1187.81    1700.43    201.62          6.89
# std      6061.88    5568.80    3813.97    3476.35     33.75          0.98
# min       -10.98       0.00       0.00       0.00    126.06          3.88
# 25%         0.00       0.00       0.00       0.00    211.26          6.49
# 50%         0.00       0.00       0.00       0.00    214.93          6.97
# 75%         9.48       5.59     577.14    2556.36    220.30          7.68
# max     92523.94   83340.33   48159.86   36430.33    226.99          8.62

# %% [markdown]
# # Time Series Example

# %%
data.groupby(date_col)[target_col].sum().plot(figsize=(12,4), grid=True)
plt.ylabel('$')
# Out:
# Text(0, 0.5, '$')

# %% [markdown]
# # Negative Values in Time Series

# %%
idx = ((data.Store == '1') & (data.Dept == '54')) # 47
data[idx].groupby(date_col)[target_col].sum().plot(figsize=(12,4), grid=True)
plt.ylabel('$')
# Out:
# Text(0, 0.5, '$')

# %% [markdown]
# # Time Series Values Distribution

# %%
data.groupby('Type').Weekly_Sales.plot.kde(figsize=(12,4), legend=True)
# Out:
# Type
# A    AxesSubplot(0.125,0.125;0.775x0.755)
# B    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Weekly_Sales, dtype: object

# %% [markdown]
# # Data Imputation Time Series

# %%
idx = ((data.Store == '1') & (data.Dept == '54')) # 47
X = data[idx].groupby(date_col)[target_col].sum()

# missing data
miss_data = np.arange(34,50)
X.iloc[miss_data] = np.nan
# Plot
X.plot(figsize=(12,4), grid=True, marker='o')

# Plot values imput mean
X.copy().fillna(Y.mean()).rename({"Weekly_Sales":"mean"}, axis=1).plot(ax=plt.gca())


# Plot Fill forward
X.copy().fillna(method='ffill').rename({"Weekly_Sales":"ffill"}, axis=1).plot(ax=plt.gca())


X.copy().fillna(method='bfill').rename({"Weekly_Sales":"bfill"}, axis=1).plot(ax=plt.gca())

X.copy().fillna(0).rename({"Weekly_Sales":"zero"}, axis=1).plot(ax=plt.gca())
plt.ylabel('$')
# Out:
# Text(0, 0.5, '$')
