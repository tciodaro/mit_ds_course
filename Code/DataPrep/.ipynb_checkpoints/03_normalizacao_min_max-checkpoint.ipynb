# %% [markdown]
# # Projeto DIVINO
# ## Normalização por Min/Max

# %%
import pandas as pd
from ipynb.fs.full.data_analiser import *

# %% [markdown]
# #### Carregando dados

# %%
dados = pd.read_csv('../../Data/Processed/wine/bigTableWines.csv')
dadosNumericos = dados.drop('Tipo Vinho', axis=1)
variavelAlvo = 'quality'
dados.head(5)
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           0            7.4              0.70         0.00             1.9
# 1           1            7.8              0.88         0.00             2.6
# 2           2            7.8              0.76         0.04             2.3
# 3           3           11.2              0.28         0.56             1.9
# 4           4            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality Tipo Vinho
# 0       0.56      9.4        5        Red
# 1       0.68      9.8        5        Red
# 2       0.65      9.8        5        Red
# 3       0.58      9.8        6        Red
# 4       0.56      9.4        5        Red

# %% [markdown]
# #### Normalizando

# %%
normed_data = normalizarPorMinMax(dadosNumericos)

# %% [markdown]
# #### KDE e Histograma comparando dados originais e normalizados

# %%
exibirHistogramaComKdeParaCadaVariavel2('Dados Originais', dadosNumericos, 'Min/Max', normed_data)

# %% [markdown]
# ### Faixa Dinâmica de Cada Variável:

# %%
exibirFaixaDinamicaDasVariaveis(normed_data)
# Out:
#                       Min  Max  Range
# Unnamed: 0            0.0  1.0    1.0
# fixed acidity         0.0  1.0    1.0
# volatile acidity      0.0  1.0    1.0
# citric acid           0.0  1.0    1.0
# residual sugar        0.0  1.0    1.0
# chlorides             0.0  1.0    1.0
# free sulfur dioxide   0.0  1.0    1.0
# total sulfur dioxide  0.0  1.0    1.0
# density               0.0  1.0    1.0
# pH                    0.0  1.0    1.0
# sulphates             0.0  1.0    1.0
# alcohol               0.0  1.0    1.0
# quality               0.0  1.0    1.0

# %% [markdown]
# ### Histograma e KDE das Variáveis

# %%
exibirHistogramaComKdeParaCadaVariavel(normed_data)

# %% [markdown]
# ### Histogramas e KDE para diferentes grupos.

# %%
exibirHistogramaComKdeParaCadaVariavelComAgrupamento(variavelAlvo, normed_data)

# %% [markdown]
# ### Coeficientes de Correlação

# %%
exibirGraficoCoeficientesDeCorrelacao(variavelAlvo, normed_data)

# %% [markdown]
# ### Scatter Matrix

# %%
exibirScatterMatrix(normed_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a325c26d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a324d5a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3261fb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32786f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32adfbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32b1ef50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32b55c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32b94f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32ba00d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32bd1950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32c3ec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32c7e4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32cb4cd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a32cf5510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32d2ad10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32d6b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32d9fd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32de0590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32e14d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32e545d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32e8bdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32ecb610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32efee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32f41650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32f73e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32fb7690>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a32feae90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3302c6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3305eed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a330a2710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a333faf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3343c750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3346ff50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a334b3790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a334e6f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a335287d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3355bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3359e810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a335d0f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a33611850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33652bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3368a890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a336c7c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a358188d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35855c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3588c910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a358cac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35903950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3593fcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35978990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a359b6d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a359ef9d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a35a2cd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35a64a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35aa2d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35ad8a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35b17dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35b4da90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35b8ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35bc3ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35c02e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35c38b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35c77e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35cadb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35ceded0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a35d24b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35d63f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35d9abd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35dd9f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35e0ec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35e4ff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35e82c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35ec2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35ef9c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35f394d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35f6ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35fae510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35fe2d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a36024550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a36057d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a36099590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a360ced90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3610f5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a36145dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a36184610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a361b9e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a361f9650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3622fe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3626f690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32520f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a324bc7d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a304b8a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3041b050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a333843d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33a5be90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a31a8b750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a31932810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a31a30310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30970d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3088a150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a339d2250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a341723d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a339a5450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2f53e6d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a35542b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a309f69d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a354adad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34ea7a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2c70b950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3450ae90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35607dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3432d3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3425b4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3477da50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32736850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a344d3b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a31a83d90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a31a105d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a319fcdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3196e050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3470de90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a328e0650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3480de50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a344c0690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a32734e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a348e16d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34787ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35172710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34ac3f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33346750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a354c1f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a341ef790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3502cf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a317197d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3435efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a340bf810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34e9ef90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24bee6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a338b7bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3448c5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34978c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34252b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3462dc50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a301c3910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3284fc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a352d7f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3451ccd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34d18990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35776d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a35610290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26f15d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a308a0a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3437ad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a351bda50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33737dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3066fa90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a331eee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33cc0ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33f39e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34d82b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33157e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2d8b3b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33bf8ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a318d5b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33f07f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a319a0bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a330f2f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33a16c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3264ff90>]],
#       dtype=object)

# %% [markdown]
# ### Analise de outlier por box-plot

# %%
exibirBoxplotPorVariavel(normed_data)
