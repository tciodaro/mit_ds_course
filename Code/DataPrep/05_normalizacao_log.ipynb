# %% [markdown]
# # Projeto DIVINO
# ## Normalização por LOG

# %%
import pandas as pd
from ipynb.fs.full.data_analiser import *

# %% [markdown]
# #### Carregando dados

# %%
dados = pd.read_csv('../../Data/Processed/wine/bigTableWines.csv')
dadosNumericos = dados.drop('Tipo Vinho', axis=1)
variavelAlvo = 'quality'
dados.head(5)
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           0            7.4              0.70         0.00             1.9
# 1           1            7.8              0.88         0.00             2.6
# 2           2            7.8              0.76         0.04             2.3
# 3           3           11.2              0.28         0.56             1.9
# 4           4            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality Tipo Vinho
# 0       0.56      9.4        5        Red
# 1       0.68      9.8        5        Red
# 2       0.65      9.8        5        Red
# 3       0.58      9.8        6        Red
# 4       0.56      9.4        5        Red

# %% [markdown]
# #### Normalizando

# %%
normed_data = normalizarPorLog(dadosNumericos)

# %% [markdown]
# #### KDE e Histograma comparando dados originais e normalizados

# %%
exibirHistogramaComKdeParaCadaVariavel2('Dados Originais', dadosNumericos, 'Log', normed_data)

# %% [markdown]
# ### Faixa Dinâmica de Cada Variável:

# %%
exibirFaixaDinamicaDasVariaveis(normed_data)
# Out:
#                        Min   Max  Range
# Unnamed: 0            0.00  8.50   8.50
# fixed acidity         1.57  2.83   1.26
# volatile acidity      0.08  0.95   0.87
# citric acid           0.00  0.98   0.98
# residual sugar        0.47  4.20   3.73
# chlorides             0.01  0.48   0.47
# free sulfur dioxide   0.69  5.67   4.98
# total sulfur dioxide  1.95  6.09   4.14
# density               0.69  0.71   0.03
# pH                    1.31  1.61   0.30
# sulphates             0.20  1.10   0.90
# alcohol               2.20  2.77   0.57
# quality               1.39  2.30   0.92

# %% [markdown]
# ### Histograma e KDE das Variáveis

# %%
exibirHistogramaComKdeParaCadaVariavel(normed_data)

# %% [markdown]
# ### Histogramas e KDE para diferentes grupos.

# %%
exibirHistogramaComKdeParaCadaVariavelComAgrupamento(variavelAlvo, normed_data)

# %% [markdown]
# ### Coeficientes de Correlação

# %%
exibirGraficoCoeficientesDeCorrelacao(variavelAlvo, normed_data)

# %% [markdown]
# ### Scatter Matrix

# %%
exibirScatterMatrix(normed_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a241d39d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b19750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25139a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a257cd110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256752d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243554d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10222a1450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236bc5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c426d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f1a650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255a01d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a242fbb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236ce4d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a247ed390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25634f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244c7790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23625e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244d7c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25097c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23efd610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2508e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c17c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24475fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245dbc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243624d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2403acd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23b0b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244efd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c39550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24844d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23daf590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2367ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236ca390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24befdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23801610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2384ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25581650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e4be50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24cd3690>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a249cee90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a253e5dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24331ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25403710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23db4f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a257d8750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ad6f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23e58790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256b5f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256fa290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256f7fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23fee810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23fd8f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2549e850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255e3bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25681890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2576bc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a246ae8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2534fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2535e910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2454fc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245470d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24129cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25606990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2427cd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255049d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a25435d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23cdda10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a237a3d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a238b6a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23739dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a239d3a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23bcce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23666ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23aa1e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a68b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b9fe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b75b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23cf9ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23e89b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24012f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24197bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a242e2f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24411c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24513f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25540c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25740fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120617c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1206fb4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1206a7cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1206e5510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f11bd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1205f8550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120684d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12076a590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1207f5d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1207aa5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120836dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120bd7610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120878e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120c17650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120c4ae50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120c8d690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120cbfe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120d006d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x120d36ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120d76710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120daaf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120ded750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120e21f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120e61790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236fdf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a237bf7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a237f1fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a238f5810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23927f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a2a850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b67bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23c9f890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d5ec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23e148d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f52c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f89910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a240c8c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2413e950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2423dcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24374990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243b1d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243e99d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24467d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2461ea10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2465cd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a246d4a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24752dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2478aa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2485ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24892ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24924e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24958b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24999e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a20b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a61ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a96b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ad7f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24b71bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24bb2f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c3cc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c79f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e69c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ea9fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24edec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a250544d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a250cccd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2510d510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25195d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251d5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2580ad50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a25849590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2587ed90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a258bf5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a258f3dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25936610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2596ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a259ad650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a259dee50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25a20690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25a55e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25a946d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25acaed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25b0b710>]],
#       dtype=object)

# %% [markdown]
# ### Analise de outlier por box-plot

# %%
exibirBoxplotPorVariavel(normed_data)
