# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn import model_selection
from sklearn import linear_model as lm
from sklearn import preprocessing
from sklearn import pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegressionCV
from sklearn import neighbors
from sklearn.calibration import CalibratedClassifierCV, calibration_curve
from sklearn import ensemble
from sklearn import tree

import os
os.environ['PATH'] = os.environ['PATH'] + ';C:/Program Files (x86)/Graphviz2.38/bin'

pandas.set_option("display.precision", 2)

input_table = '../../Data/Processed/wine/winequality.parquet'

feature_norm  = True


target_variable = ['quality']
classifier_variables = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                      'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
                      'pH', 'sulphates', 'alcohol']

# %%
# %run functions.ipynb

# %% [markdown]
# # Leitura dos dados

# %%
data = pandas.read_parquet(input_table)
print('data shape:', data.shape)
print('data columns:', data.columns.tolist())
# Out:
# data shape: (6497, 14)
# data columns: ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality', 'red', 'white']

# %% [markdown]
# # Normalização dos dados

# %%
if feature_norm:
    data[classifier_variables] = preprocessing.power_transform(data[classifier_variables], method='yeo-johnson')
# Out:
# C:\Users\cammy\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2982: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %% [markdown]
# # Validação Cruzada

# %%
X = data[classifier_variables].values
Y = data[target_variable].values
idx = Y > 5
classes=['baixa qualidade','alta qualidade']
Y[idx] = 1
Y[~idx]= 0

# Dividir 20% dos dados para o conjunto out-of-sample de teste
Xtrain, Xtest, Ytrain, Ytest = model_selection.train_test_split(X,
                                                                Y,
                                                                test_size=0.2,
                                                                random_state=0,
                                                                stratify=Y)

# Objeto de validacao cruzada
cvfold = model_selection.StratifiedKFold(n_splits = 10, random_state = 0)
# Out:
# C:\Users\cammy\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# # Regressão Logística
# ## Curvas de Aprendizado

# %%
plt.figure()

scorer = metrics.make_scorer(metrics.accuracy_score)

title = "Curva de Aprendizado (Regressão Logística)"
estimatorLR = LogisticRegressionCV(random_state=0)
plot_learning_curve(estimatorLR, title, Xtrain, Ytrain, ax=plt.gca(),
                    cv=cvfold.split(Xtrain, Ytrain, groups=Ytrain),
                    scoring=scorer, n_jobs=3)

# %% [markdown]
# ## Pipeline de Treinamento

# %%
# Configure Pipeline
conf_train_pipe_LR = [
    ('Scaler', StandardScaler()),
    ('Model', LogisticRegressionCV(Cs=10, cv=cvfold, random_state = 0)),
]

# Create Pipeline
model_pipe_LR = pipeline.Pipeline(conf_train_pipe_LR)


model_pipe_LR.fit(Xtrain, Ytrain)
# Out:
# C:\Users\cammy\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(memory=None,
#          steps=[('Scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('Model',
#                  LogisticRegressionCV(Cs=10, class_weight=None,
#                                       cv=StratifiedKFold(n_splits=10, random_state=0, shuffle=False),
#                                       dual=False, fit_intercept=True,
#                                       intercept_scaling=1.0, l1_ratios=None,
#                                       max_iter=100, multi_class='auto',
#                                       n_jobs=None, penalty='l2', random_state=0,
#                                       refit=True, scoring=None, solver='lbfgs',
# ...

# %% [markdown]
# ## Estimativa do modelo

# %%
decision_threshold = 0.535
YhatLR = model_pipe_LR.predict_proba(Xtest)[:,1]
YpredLR= YhatLR >= decision_threshold

print('Yhat.shape:', YhatLR.shape)
# Out:
# Yhat.shape: (1300,)

# %% [markdown]
# ## Distribuição

# %%
for i in range(len(classes)):
    # 2 Classes case
    sns.distplot(YhatLR[Ytest[:,0] == i], label=classes[i])

plt.title('Regressão Logística')
plt.ylabel('Densidade Estimada KDE')
plt.xlabel('Probabilidade Vinho Alta Qualidade')
plt.grid()
plt.legend()

# %% [markdown]
# ## Curva ROC

# %%
plt.figure()
fpr, tpr, thr = metrics.roc_curve(Ytest, YhatLR)
auc = metrics.roc_auc_score(Ytest, YhatLR)
plt.plot(fpr, tpr, '-', lw=2, label='AUC: %.2f'%(auc))
plt.legend()
plt.title('Classificador Vinhos de Alta Qualidade')
plt.grid()
plt.xlabel('Taxa de Falso Alarme')
plt.ylabel('Taxa de Detecção')
# Out:
# Text(0, 0.5, 'Taxa de Detecção')

# %% [markdown]
# ## Matriz de Confusão

# %%
col_names = ['Model ' + s for s in classes]
idx_names = ['Real ' + s for s in classes]

cmatLR = metrics.confusion_matrix(Ytest, YpredLR)
cmatLR = pandas.DataFrame(cmatLR, index=idx_names,
                              columns=col_names)
cmatLR['Real Total'] = cmatLR.sum(axis=1)
cmatLR.loc['Model Total',:] = cmatLR.sum(axis=0)
cmatLR = cmatLR.astype(int)
cmatLR
# Out:
#                       Model baixa qualidade  Model alta qualidade  Real Total
# Real baixa qualidade                    299                   178         477
# Real alta qualidade                     172                   651         823
# Model Total                             471                   829        1300

# %% [markdown]
# ## Classification Report

# %%
print(metrics.classification_report(Ytest, YpredLR, target_names=classes))
# Out:
#                  precision    recall  f1-score   support
#
# baixa qualidade       0.63      0.63      0.63       477
#  alta qualidade       0.79      0.79      0.79       823
#
#        accuracy                           0.73      1300
#       macro avg       0.71      0.71      0.71      1300
#    weighted avg       0.73      0.73      0.73      1300

# %% [markdown]
# ## Scores da Validacao Cruzada

# %%
obj = model_pipe_LR.steps[1][1] # pega o objeto Regressao Logistica do pipeline
for icv, score in enumerate(obj.scores_[1][:,0]):
    print('CV', icv, ":", score)
print('CV Summary:', obj.scores_[1][:,0].mean(), "+-", obj.scores_[1][:,0].std())
# Out:
# CV 0 : 0.6326923076923077
# CV 1 : 0.6326923076923077
# CV 2 : 0.6326923076923077
# CV 3 : 0.6326923076923077
# CV 4 : 0.6326923076923077
# CV 5 : 0.6326923076923077
# CV 6 : 0.6326923076923077
# CV 7 : 0.6339113680154143
# CV 8 : 0.6339113680154143
# CV 9 : 0.6339113680154143
# CV Summary: 0.6330580257892395 +- 0.0005586436207353278

# %% [markdown]
# ## Calibration Plot

# %%
# Calibrated with sigmoid calibration
calib_sigmoid = CalibratedClassifierCV(model_pipe_LR, cv=5, method='sigmoid')
calib_sigmoid.fit(Xtrain, Ytrain)
Ypred_calib = calib_sigmoid.predict(Xtest)
Yhat_calib  = calib_sigmoid.predict_proba(Xtest)[:,1]


# Modelo perfeito
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")

# Modelo logistico puro
clf_score = metrics.brier_score_loss(Ytest, YhatLR, pos_label=1)
fraction_of_positives, mean_predicted_value = calibration_curve(Ytest, YhatLR, n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="Logistic (%1.3f)" %clf_score)

# Modelo calibrado
clf_score = metrics.brier_score_loss(Ytest, Yhat_calib, pos_label=1)
fraction_of_positives, mean_predicted_value = calibration_curve(Ytest, Yhat_calib, n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="Calibrado (%1.3f)" %clf_score)


plt.ylabel("Fração de Positivos Classificados")
plt.xlabel("Valor Médio Previsto de Positivos")
plt.ylim([-0.05, 1.05])
plt.title('Curvas de Calibração')
plt.legend()
plt.grid()
# Out:
# C:\Users\cammy\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # KNN
# ## Curvas de aprendizado

# %%
plt.figure()

scorer = metrics.make_scorer(metrics.accuracy_score)

title = "Curva de Aprendizado (kNN)"
estimatorKNN = neighbors.KNeighborsClassifier()
plot_learning_curve(estimatorKNN, title, Xtrain, Ytrain, ax=plt.gca(),
                    cv=cvfold.split(Xtrain, Ytrain, groups=Ytrain),
                    scoring=scorer, n_jobs=3)

# %% [markdown]
# ## Pipeline de treinamento

# %%
param_range = [4, 6, 8, 10, 12, 16, 20]

# Configure Pipeline
conf_train_pipe_KNN = [
    ('Scaler', StandardScaler()),
    ('Model', neighbors.KNeighborsClassifier()),
]

# Create Pipeline
model_pipe_KNN = pipeline.Pipeline(conf_train_pipe_KNN)

param_grid = {
    'Model__n_neighbors': param_range,
    'Model__weights' : ['uniform','distance']
}

model_pipe_KNN = model_selection.GridSearchCV(model_pipe_KNN, param_grid,
                                     scoring=None,
                                     cv=cvfold,
                                     return_train_score=True)

model_pipe_KNN.fit(Xtrain, Ytrain.ravel())
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=0, shuffle=False),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('Scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('Model',
#                                         KNeighborsClassifier(algorithm='auto',
#                                                              leaf_size=30,
#                                                              metric='minkowski',
#                                                              metric_params=None,
#                                                              n_jobs=None,
#                                                              n_neighbors=5, p=2,
# ...

# %% [markdown]
# ## Estimativa do Modelo

# %%
YhatKNN = model_pipe_KNN.predict_proba(Xtest)[:,1]
YpredKNN= model_pipe_KNN.predict(Xtest)
print('Yhat.shape:', YhatKNN.shape)
# Out:
# Yhat.shape: (1300,)

# %% [markdown]
# ## Calibration Plot

# %%
# Calibrated with sigmoid calibration
calib_sigmoid = CalibratedClassifierCV(model_pipe_KNN, cv=5, method='sigmoid')
calib_sigmoid.fit(Xtrain, Ytrain.ravel())
Ypred_calib = calib_sigmoid.predict(Xtest)
Yhat_calib  = calib_sigmoid.predict_proba(Xtest)[:,1]


# Modelo perfeito
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")

# Modelo logistico puro
clf_score = metrics.brier_score_loss(Ytest, YhatKNN, pos_label=1)
fraction_of_positives, mean_predicted_value = calibration_curve(Ytest, YhatKNN, n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="kNN (%1.3f)" %clf_score)

# Modelo calibrado
clf_score = metrics.brier_score_loss(Ytest, Yhat_calib, pos_label=1)
fraction_of_positives, mean_predicted_value = calibration_curve(Ytest, Yhat_calib, n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="Calibrado (%1.3f)" %clf_score)


plt.ylabel("Fração de Positivos Classificados")
plt.xlabel("Valor Médio Previsto de Positivos")
plt.ylim([-0.05, 1.05])
plt.title('Curvas de Calibração')
plt.legend()
plt.grid()

# %% [markdown]
# ## Dristribuições

# %%
for i in range(len(classes)):
    # 2 Classes case
    sns.distplot(Yhat_calib[Ytest.ravel() == i], label=classes[i])

plt.title('KNN')
plt.ylabel('Densidade Estimada KDE')
plt.xlabel('Probabilidade Vinho Alta Qualidade')
plt.grid()
plt.legend()

# %% [markdown]
# ## Curva ROC

# %%
# help(metrics.roc_curve)
plt.figure()
fpr, tpr, thr = metrics.roc_curve(Ytest, Yhat_calib)
auc = metrics.roc_auc_score(Ytest, Yhat_calib)
plt.plot(fpr, tpr, '-', lw=2, label='AUC: %.2f'%(auc))
plt.legend()
plt.title('Classificador Vinhos de Alta Qualidade')
plt.grid()
plt.xlabel('Taxa de Falso Alarme')
plt.ylabel('Taxa de Detecção')
# Out:
# Text(0, 0.5, 'Taxa de Detecção')

# %% [markdown]
# ## Matriz de Confusão

# %%
col_names = ['Model ' + s for s in classes]
idx_names = ['Real ' + s for s in classes]

cmat = metrics.confusion_matrix(Ytest, Ypred_calib)
cmat = pandas.DataFrame(cmat, index=idx_names,
                              columns=col_names)
cmat['Real Total'] = cmat.sum(axis=1)
cmat.loc['Model Total',:] = cmat.sum(axis=0)
cmat = cmat.astype(int)
cmat
# Out:
#                       Model baixa qualidade  Model alta qualidade  Real Total
# Real baixa qualidade                    352                   125         477
# Real alta qualidade                      91                   732         823
# Model Total                             443                   857        1300

# %% [markdown]
# ## Classification Report

# %%
print(metrics.classification_report(Ytest.ravel(), Ypred_calib, target_names=classes))
# Out:
#                  precision    recall  f1-score   support
#
# baixa qualidade       0.79      0.74      0.77       477
#  alta qualidade       0.85      0.89      0.87       823
#
#        accuracy                           0.83      1300
#       macro avg       0.82      0.81      0.82      1300
#    weighted avg       0.83      0.83      0.83      1300

# %% [markdown]
# ## Scores da Validacao Cruzada

# %%
print('Train')
print('\tScore:', np.mean(model_pipe_KNN.cv_results_['mean_train_score']),
       '+-'     , np.mean(model_pipe_KNN.cv_results_['std_train_score']))
print('Test')
print('\tScore:', np.mean(model_pipe_KNN.cv_results_['mean_test_score']),
       '+-'     , np.mean(model_pipe_KNN.cv_results_['std_test_score']))
# Out:
# Train
# 	Score: 0.9019779306766889 +- 0.001292719512093347
# Test
# 	Score: 0.7817404296089269 +- 0.0150915135745404

# %% [markdown]
# ## Melhores Parâmetros

# %%
model_pipe_KNN.best_params_
# Out:
# {'Model__n_neighbors': 12, 'Model__weights': 'distance'}

# %% [markdown]
# # Random Forest
# ## Curva de aprendizado

# %%
plt.figure()

scorer = metrics.make_scorer(metrics.accuracy_score)

title = "Curva de Aprendizado Random Forest"
estimatorRF = ensemble.RandomForestClassifier()
plot_learning_curve(estimatorRF, title, Xtrain, Ytrain.ravel(), ax=plt.gca(),
                    cv=cvfold.split(Xtrain, Ytrain, groups=Ytrain),
                    scoring=scorer, n_jobs=1)

# %% [markdown]
# ## Pipeline de treinamento

# %%
# Configure Pipeline
conf_train_pipe_RF = [
    ('Scaler', StandardScaler()),
    ('Model', ensemble.RandomForestClassifier()),
]

# Create Pipeline
model_pipe_RF = pipeline.Pipeline(conf_train_pipe_RF)

param_grid = {
    'Model__max_depth': [4,5,6,7,8,9,10],
    'Model__n_estimators' : [10, 20, 40, 50, 100],
    'Model__max_features' : ['sqrt','log2'],
}

model_pipe_RF = model_selection.GridSearchCV(model_pipe_RF, param_grid,
                                     scoring=None,
                                     cv=cvfold,
                                     return_train_score=True)

model_pipe_RF.fit(Xtrain, Ytrain.ravel())
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=0, shuffle=False),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('Scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('Model',
#                                         RandomForestClassifier(bootstrap=True,
#                                                                ccp_alpha=0.0,
#                                                                class_weight=None,
#                                                                criterion='gini',
#                                                                max_depth=None,
#                                                                max_features='auto',
# ...

# %% [markdown]
# ## Estimativa do Modelo

# %%
YhatRF = model_pipe_RF.predict_proba(Xtest)[:,1]
YpredRF= model_pipe_RF.predict(Xtest)
print('Yhat.shape:', YhatRF.shape)
# Out:
# Yhat.shape: (1300,)

# %% [markdown]
# ## Calibration Plot

# %%
model_name = "Random Forest"
# Calibrated with sigmoid calibration
calib_sigmoid = CalibratedClassifierCV(model_pipe_RF, cv=5, method='sigmoid')
calib_sigmoid.fit(Xtrain, Ytrain.ravel())
Ypred_calib = calib_sigmoid.predict(Xtest)
Yhat_calib  = calib_sigmoid.predict_proba(Xtest)[:,1]


# Modelo perfeito
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")

# Modelo logistico puro
clf_score = metrics.brier_score_loss(Ytest, YhatRF, pos_label=1)
fraction_of_positives, mean_predicted_value = calibration_curve(Ytest, YhatRF, n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,
         "s-", label=model_name + " (%1.3f)" %clf_score)

# Modelo calibrado
clf_score = metrics.brier_score_loss(Ytest, Yhat_calib, pos_label=1)
fraction_of_positives, mean_predicted_value = calibration_curve(Ytest, Yhat_calib, n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,
         "s-", label="Calibrado (%1.3f)" %clf_score)


plt.ylabel("Fração de Positivos Classificados")
plt.xlabel("Valor Médio Previsto de Positivos")
plt.ylim([-0.05, 1.05])
plt.title('Curvas de Calibração')
plt.legend()
plt.grid()

# %% [markdown]
# ## Distribuições

# %%
for i in range(len(classes)):
    # 2 Classes case
    sns.distplot(Yhat_calib[Ytest.ravel() == i], label=classes[i])

plt.title('Random Forest')
plt.ylabel('Densidade Estimada KDE')
plt.xlabel('Probabilidade Vinho Alta Qualidade')
plt.grid()
plt.legend()

# %% [markdown]
# ## Curvas ROC

# %%
plt.figure()
fpr, tpr, thr = metrics.roc_curve(Ytest, Yhat_calib)
auc = metrics.roc_auc_score(Ytest, Yhat_calib)
plt.plot(fpr, tpr, '-', lw=2, label = model_name + ' AUC: %.2f'%(auc))
plt.legend()
plt.title('Classificador Vinhos de Alta Qualidade')
plt.grid()
plt.xlabel('Taxa de Falso Alarme')
plt.ylabel('Taxa de Detecção')
# Out:
# Text(0, 0.5, 'Taxa de Detecção')

# %% [markdown]
# ## Matriz de Confusão

# %%
col_names = ['Model ' + s for s in classes]
idx_names = ['Real ' + s for s in classes]

cmat = metrics.confusion_matrix(Ytest, Ypred_calib)
cmat = pandas.DataFrame(cmat, index=idx_names,
                              columns=col_names)
cmat['Real Total'] = cmat.sum(axis=1)
cmat.loc['Model Total',:] = cmat.sum(axis=0)
cmat = cmat.astype(int)
cmat
# Out:
#                       Model baixa qualidade  Model alta qualidade  Real Total
# Real baixa qualidade                    334                   143         477
# Real alta qualidade                     111                   712         823
# Model Total                             445                   855        1300

# %% [markdown]
# ## Classification Report

# %%
print(metrics.classification_report(Ytest, Ypred_calib, target_names=classes))
# Out:
#                  precision    recall  f1-score   support
#
# baixa qualidade       0.75      0.70      0.72       477
#  alta qualidade       0.83      0.87      0.85       823
#
#        accuracy                           0.80      1300
#       macro avg       0.79      0.78      0.79      1300
#    weighted avg       0.80      0.80      0.80      1300

# %% [markdown]
# ## Scores da Validação Cruzada

# %%
print('Train')
print('\tScore:', np.mean(model_pipe_RF.cv_results_['mean_train_score']),
       '+-'     , np.mean(model_pipe_RF.cv_results_['std_train_score']))
print('Test')
print('\tScore:', np.mean(model_pipe_RF.cv_results_['mean_test_score']),
       '+-'     , np.mean(model_pipe_RF.cv_results_['std_test_score']))
# Out:
# Train
# 	Score: 0.8323452496620994 +- 0.0032096940560830713
# Test
# 	Score: 0.7748271136378074 +- 0.017290713657469585

# %% [markdown]
# ## Melhores Parâmetros

# %%
model_pipe_RF.best_params_
# Out:
# {'Model__max_depth': 10,
#  'Model__max_features': 'log2',
#  'Model__n_estimators': 100}

# %% [markdown]
# ## Visualização de um dos estimadores

# %%
import graphviz

clf = model_pipe_RF.best_estimator_.steps[1][1].estimators_[0]

dot_data = tree.export_graphviz(clf, out_file=None, 
                      feature_names=classifier_variables,
                      class_names=classes,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# # Exportação do Resultado

# %%
test_data = [Xtest[0], Ytest,]
#df_cols = classifier_variables
df_cols = ['text', 'class']

model_name = 'LogisticRegretion'
test_data.append(YhatLR)
df_cols.append(model_name)

model_name = 'KNN'
test_data.append(YhatKNN)
df_cols.append(model_name)

model_name = 'RandomForest'
test_data.append(YhatRF)
df_cols.append(model_name)

        
test_data = np.array(test_data).T
df_test = pandas.DataFrame(data=test_data, columns=df_cols)

df_test.to_excel('../../Data/Modeling/results.xlsx')

df_test.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1653                 blocks = [
# -> 1654                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1655                 ]
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3040
# -> 3041     return klass(values, ndim=ndim, placement=placement)
#    3042
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2588
# -> 2589         super().__init__(values, ndim=ndim, placement=placement)
#    2590
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     124             raise ValueError(
# ...

# %%
df_cols
# Out:
# ['text', 'class', 'LogisticRegretion', 'KNN', 'RandomForest']

# %%
test_data
# Out:
# array([array([-0.18923731, -0.36976997,  0.19125829,  1.4528341 , -0.99393972,
#         0.60013282,  0.35133195,  0.        ,  0.73283542,  0.18184663,
#         1.23818624]),
#        array([[1],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]], dtype=int64),
#        array([0.95433872, 0.25457098, 0.43075145, ..., 0.47903392, 0.9658544 ,
#        0.86813714]),
#        array([1.        , 0.22441471, 0.        , ..., 1.        , 0.84729945,
#        1.        ]),
#        array([0.95544038, 0.26458524, 0.49107789, ..., 0.79845619, 0.88427872,
#        0.79238806])], dtype=object)
