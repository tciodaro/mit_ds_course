# %% [markdown]
# # Reefetuar as análises com a normalização por log
#
# ## Definição de pronto
#
# ### Dados preparados no ambiente
#
# ## Definição de entregue
#
# ### Notebook fazendo a avaliação

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as sklpp

pd.set_option("display.precision", 4)

df_wine = pd.read_parquet("../../Data/Processed/wine/df_wine.parquet")

# %%
''' Criando dataframe normalizado'''

''' Referência: https://scikit-learn.org/stable/modules/preprocessing.html'''
'''             https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame'''
'''             https://scikit-learn.org/stable/modules/preprocessing.html'''

# Usando FunctionTransformer para usar função log1p de numpy para normalizar cada coluna
# Usar log dá divisão por zero

function_transformer = sklpp.FunctionTransformer

transformer = function_transformer(np.log1p, validate=True)

df_wine_normalizado = pd.DataFrame(transformer.transform(df_wine.drop(['type'], axis = 1)))

# scikit learn retira as colunas do dataframe modificado. Colocando-as de volta
df_wine_normalizado.columns = df_wine.drop(['type'], axis = 1).columns

# visualização da normalização
df_wine_normalizado.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         2.1282            0.5306       0.0000          1.0647     0.0733
# 1         2.1748            0.6313       0.0000          1.2809     0.0935
# 2         2.1748            0.5653       0.0392          1.1939     0.0880
# 3         2.5014            0.2469       0.4447          1.0647     0.0723
# 4         2.1282            0.5306       0.0000          1.0647     0.0733
#
#    free sulfur dioxide  total sulfur dioxide  density      pH  sulphates  \
# 0               2.4849                3.5553   0.6920  1.5063     0.4447
# 1               3.2581                4.2195   0.6915  1.4351     0.5188
# 2               2.7726                4.0073   0.6916  1.4493     0.5008
# 3               2.8904                4.1109   0.6921  1.4255     0.4574
# 4               2.4849                3.5553   0.6920  1.5063     0.4447
#
#    alcohol  quality
# 0   2.3418   1.7918
# 1   2.3795   1.7918
# 2   2.3795   1.7918
# 3   2.3795   1.9459
# 4   2.3418   1.7918

# %% [markdown]
# ## Refazendo as análises

# %%
''' Estatísticas Gerais'''

df_wine_normalizado.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      6497.0000         6497.0000    6497.0000       6497.0000
# mean          2.0949            0.2855       0.2706          1.6207
# std           0.1450            0.1148       0.1099          0.6821
# min           1.5686            0.0770       0.0000          0.4700
# 25%           2.0015            0.2070       0.2231          1.0296
# 50%           2.0794            0.2546       0.2700          1.3863
# 75%           2.1633            0.3365       0.3293          2.2083
# max           2.8273            0.9478       0.9783          4.2017
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  6497.0000            6497.0000             6497.0000  6497.0000
# mean      0.0540               3.2672                4.5783     0.6905
# std       0.0308               0.6555                0.6991     0.0015
# min       0.0090               0.6931                1.9459     0.6867
# 25%       0.0373               2.8904                4.3567     0.6893
# 50%       0.0459               3.4012                4.7791     0.6906
# 75%       0.0630               3.7377                5.0562     0.6916
# max       0.4769               5.6699                6.0890     0.7124
#
#               pH  sulphates    alcohol    quality
# count  6497.0000  6497.0000  6497.0000  6497.0000
# mean      1.4388     0.4217     2.4364     1.9113
# std       0.0379     0.0916     0.1017     0.1295
# min       1.3137     0.1989     2.1972     1.3863
# 25%       1.4134     0.3577     2.3514     1.7918
# 50%       1.4375     0.4121     2.4248     1.9459
# 75%       1.4633     0.4700     2.5096     1.9459
# max       1.6114     1.0986     2.7663     2.3026

# %%
'''' Avaliar a faixa dimâmica por variável'''

''' Loop por colunas do df retirando a coluna type que é do tipo string formatando o resultado em 2 casa decimais'''

for (column, _ ) in df_wine_normalizado.items():
    print(f'{column} \t faixa dinâmica: \t {"{:.2f}".format(df_wine_normalizado[column].max() - df_wine_normalizado[column].min())}')
# Out:
# fixed acidity 	 faixa dinâmica: 	 1.26
# volatile acidity 	 faixa dinâmica: 	 0.87
# citric acid 	 faixa dinâmica: 	 0.98
# residual sugar 	 faixa dinâmica: 	 3.73
# chlorides 	 faixa dinâmica: 	 0.47
# free sulfur dioxide 	 faixa dinâmica: 	 4.98
# total sulfur dioxide 	 faixa dinâmica: 	 4.14
# density 	 faixa dinâmica: 	 0.03
# pH 	 faixa dinâmica: 	 0.30
# sulphates 	 faixa dinâmica: 	 0.90
# alcohol 	 faixa dinâmica: 	 0.57
# quality 	 faixa dinâmica: 	 0.92

# %%
''' Histogramas com as distribuições das variáveis'''

''' Referência: https://matplotlib.org/gallery/index.html'''

for (column, _ ) in df_wine_normalizado.items():
    plt.figure()
    df_wine_normalizado[column].plot.hist(figsize=(15,5), legend=True);
    plt.legend(ncol = 1)
    plt.title(column)

# %%
''' Utilizar KDE - Kernel Density Estimate '''

''' Referência: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.kde.html '''

for (column, _ ) in df_wine_normalizado.items():
    plt.figure()
    df_wine_normalizado[column].plot.kde(figsize=(15,5), legend=True);
    plt.legend(ncol = 1)
    plt.title(column)

# %%
''' Correlação entre as variáveis'''

df_wine_normalizado.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                1.0000            0.2221       0.3058
# volatile acidity             0.2221            1.0000      -0.4082
# citric acid                  0.3058           -0.4082       1.0000
# residual sugar              -0.0905           -0.1702       0.1417
# chlorides                    0.3147            0.3974       0.0046
# free sulfur dioxide         -0.3324           -0.3983       0.1365
# total sulfur dioxide        -0.3787           -0.4683       0.2071
# density                      0.4656            0.2733       0.0784
# pH                          -0.2705            0.2531      -0.3420
# sulphates                    0.2879            0.2379       0.0353
# alcohol                     -0.1087           -0.0355      -0.0064
# quality                     -0.0853           -0.2724       0.1029
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity                -0.0905     0.3147              -0.3324
# volatile acidity             -0.1702     0.3974              -0.3983
# citric acid                   0.1417     0.0046               0.1365
# residual sugar                1.0000    -0.1315               0.4014
# chlorides                    -0.1315     1.0000              -0.2594
# free sulfur dioxide           0.4014    -0.2594               1.0000
# total sulfur dioxide          0.4303    -0.3490               0.7810
# density                       0.5136     0.3842              -0.0491
# pH                           -0.2578     0.0550              -0.1465
# sulphates                    -0.1863     0.3836              -0.2269
# alcohol                      -0.3354    -0.2693              -0.1455
# quality                      -0.0145    -0.2061               0.1183
#
#                       total sulfur dioxide  density      pH  sulphates  \
# fixed acidity                      -0.3787   0.4656 -0.2705     0.2879
# volatile acidity                   -0.4683   0.2733  0.2531     0.2379
# citric acid                         0.2071   0.0784 -0.3420     0.0353
# residual sugar                      0.4303   0.5136 -0.2578    -0.1863
# chlorides                          -0.3490   0.3842  0.0550     0.3836
# free sulfur dioxide                 0.7810  -0.0491 -0.1465    -0.2269
# total sulfur dioxide                1.0000  -0.1045 -0.2512    -0.3259
# density                            -0.1045   1.0000  0.0113     0.2685
# pH                                 -0.2512   0.0113  1.0000     0.2103
# sulphates                          -0.3259   0.2685  0.2103     1.0000
# alcohol                            -0.1885  -0.6890  0.1279    -0.0039
# quality                             0.0121  -0.2957  0.0173     0.0393
#
#                       alcohol  quality
# fixed acidity         -0.1087  -0.0853
# volatile acidity      -0.0355  -0.2724
# citric acid           -0.0064   0.1029
# residual sugar        -0.3354  -0.0145
# chlorides             -0.2693  -0.2061
# free sulfur dioxide   -0.1455   0.1183
# total sulfur dioxide  -0.1885   0.0121
# density               -0.6890  -0.2957
# pH                     0.1279   0.0173
# sulphates             -0.0039   0.0393
# alcohol                1.0000   0.4279
# quality                0.4279   1.0000

# %%
''' Scatter Plot'''

''' Referência: https://seaborn.pydata.org/generated/seaborn.pairplot.html'''

import seaborn as sb
sb.pairplot(df_wine_normalizado)

# %%
''' Box Plot'''
''' Referência: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html'''

for (column_name, _ ) in df_wine_normalizado.items():
    plt.figure()
    df_wine_normalizado.boxplot(column = column_name)
    plt.title(column_name)
