# %%
import pandas
import numpy as np

pandas.set_option("display.precision", 2)

input_table = '../../Data/Processed/wine/bigtable_data.parquet'

# %% [markdown]
# # Load Data

# %%
data = pandas.read_parquet(input_table)
print('data shape:', data.shape)
print('data columns:', data.columns.tolist())
data.head()
# Out:
# data shape: (6497, 13)
# data columns: ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality', 'type']
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9       0.08
# 1            7.8              0.88         0.00             2.6       0.10
# 2            7.8              0.76         0.04             2.3       0.09
# 3           11.2              0.28         0.56             1.9       0.07
# 4            7.4              0.70         0.00             1.9       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0      1.0  3.51       0.56
# 1                 25.0                  67.0      1.0  3.20       0.68
# 2                 15.0                  54.0      1.0  3.26       0.65
# ...

# %% [markdown]
# # Data Description

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        6497.00           6497.00      6497.00         6497.00
# mean            7.22              0.34         0.32            5.44
# std             1.30              0.16         0.15            4.76
# min             3.80              0.08         0.00            0.60
# 25%             6.40              0.23         0.25            1.80
# 50%             7.00              0.29         0.31            3.00
# 75%             7.70              0.40         0.39            8.10
# max            15.90              1.58         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# count   6.50e+03              6497.00               6497.00  6.50e+03
# mean    5.60e-02                30.53                115.74  9.95e-01
# std     3.50e-02                17.75                 56.52  3.00e-03
# min     9.00e-03                 1.00                  6.00  9.87e-01
# ...

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                  1.00              0.22         0.32
# volatile acidity               0.22              1.00        -0.38
# citric acid                    0.32             -0.38         1.00
# residual sugar                -0.11             -0.20         0.14
# chlorides                      0.30              0.38         0.04
# free sulfur dioxide           -0.28             -0.35         0.13
# total sulfur dioxide          -0.33             -0.41         0.20
# density                        0.46              0.27         0.10
# pH                            -0.25              0.26        -0.33
# sulphates                      0.30              0.23         0.06
# alcohol                       -0.10             -0.04        -0.01
# quality                       -0.08             -0.27         0.09
# type                          -0.49             -0.65         0.19
#
# ...

# %% [markdown]
# # Gráficos

# %%
import matplotlib.pyplot as plt

# %%
for cname in data.columns:
    plt.figure()
    data[cname].hist()
    plt.title(cname)

# %%
for cname in data.columns:
    plt.figure()
    data[cname].plot.kde()
    plt.title(cname)

# %%
for cname in data.columns[:len(data.columns)-2]:
    plt.figure()
    data.groupby('quality')[cname].plot.kde(legend=True)
    plt.title(cname)

# %%
data.corr()['quality'].drop('quality').plot.bar()

# %%
for cname in data.columns:
    plt.figure()
    data.boxplot(column=cname)
    plt.title(cname)

# %%
pandas.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022C8E1B45C8>,
# ...
#       dtype=object)

# %%
import seaborn as sns
sns.pairplot(data)
