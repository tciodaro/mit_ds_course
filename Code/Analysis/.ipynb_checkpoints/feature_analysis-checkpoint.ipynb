# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pandas.set_option("display.precision", 2)

input_table = '../../Data/Processed/wine/winequality.parquet'

# %% [markdown]
# # Leitura dos dados

# %%
data = pandas.read_parquet(input_table)
print('data shape:', data.shape)
print('data columns:', data.columns.tolist())
# Out:
# data shape: (6497, 14)
# data columns: ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality', 'red', 'white']

# %% [markdown]
# # Distribuição dos dados

# %%
for cname in data.columns:
    plt.figure()
    data[cname].plot.kde()
    plt.title(cname)

# %% [markdown]
# # Distribuição agrupada pela qualidade

# %%
for cname in data.columns[:len(data.columns)-3]:
    plt.figure()
    data.groupby('quality')[cname].plot.kde(legend=True)
    plt.title(cname)

# %% [markdown]
# ## Correlação com a variável alvo - qualidade

# %%
data.corr()['quality'].drop('quality').plot.bar()

# %%
sns.pairplot(data, kind="reg")

# %%
sns.pairplot(data, hue="quality", vars=["fixed acidity", "volatile acidity", "citric acid", "chlorides", "density", "alcohol"])
