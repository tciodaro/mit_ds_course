# %% [markdown]
# # Plot-scatter para cada variável (pandas)
#
# ## Definição de pronto
#
# ### Dados preparados no ambiente
#
# ## Definição de entregue
#
# ### Notebook fazendo a avaliação

# %%
import pandas as pd

pd.set_option("display.precision", 4)

df_wine = pd.read_parquet("../../Data/Processed/wine/df_wine.parquet")

# %%
''' Plot-Scatter '''
''' Referência https://pandas.pydata.org/docs/reference/api/pandas.plotting.scatter_matrix.html'''

pd.plotting.scatter_matrix(df_wine, figsize=(18,18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f15e4a2a8b0>,
# ...
#       dtype=object)
