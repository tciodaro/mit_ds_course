# %% [markdown]
# # Projeto DIVINO
# ## Normalização por LOG

# %%
import pandas as pd
from ipynb.fs.full.data_analiser import *

# %% [markdown]
# #### Carregando dados

# %%
dados = pd.read_csv('../Data/Processed/wine/bigTableWines.csv', sep=";")
dadosNumericos = dados.drop('Tipo Vinho', axis=1)
variavelAlvo = 'quality'
dados.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality Tipo Vinho
# 0      9.4        5        Red
# 1      9.8        5        Red
# 2      9.8        5        Red
# 3      9.8        6        Red
# 4      9.4        5        Red

# %% [markdown]
# #### Normalizando

# %%
normed_data = normalizarPorLog(dadosNumericos)

# %% [markdown]
# #### KDE e Histograma comparando dados originais e normalizados

# %%
exibirHistogramaComKdeParaCadaVariavel2('Dados Originais', dadosNumericos, 'Log', normed_data)

# %% [markdown]
# ### Faixa Dinâmica de Cada Variável:

# %%
exibirFaixaDinamicaDasVariaveis(normed_data)
# Out:
#                        Min   Max  Range
# fixed acidity         1.57  2.83   1.26
# volatile acidity      0.08  0.95   0.87
# citric acid           0.00  0.98   0.98
# residual sugar        0.47  4.20   3.73
# chlorides             0.01  0.48   0.47
# free sulfur dioxide   0.69  5.67   4.98
# total sulfur dioxide  1.95  6.09   4.14
# density               0.69  0.71   0.03
# pH                    1.31  1.61   0.30
# sulphates             0.20  1.10   0.90
# alcohol               2.20  2.77   0.57
# quality               1.39  2.30   0.92

# %% [markdown]
# ### Histograma e KDE das Variáveis

# %%
exibirHistogramaComKdeParaCadaVariavel(normed_data)

# %% [markdown]
# ### Histogramas e KDE para diferentes grupos.

# %%
exibirHistogramaComKdeParaCadaVariavelComAgrupamento(variavelAlvo, normed_data)

# %% [markdown]
# ### Coeficientes de Correlação

# %%
exibirGraficoCoeficientesDeCorrelacao(variavelAlvo, normed_data)

# %% [markdown]
# ### Scatter Matrix

# %%
exibirScatterMatrix(normed_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a242393d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248f2d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255039d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2588ed50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24918a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25537d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a259eba50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25387290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25387dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2521c790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25879ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25b3de50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a259c8b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25737e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b29b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255beed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f63c250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2532e0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25a431d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2321ad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22caf9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25aae110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25681350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a76d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a229ac890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2560f990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25675450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2366e250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2299f950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a69090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a202dcf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fbbbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fe7590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22917490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21bccf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21bb8c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a21c81ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22850690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21979350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23071990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1efecd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2347fdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22d689d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25abe810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25ad6f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a6ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2577ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22edfc90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2320c4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25642cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25a9b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255e6d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22e49550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25797d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22d1d590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25686d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2282b850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22cdddd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2594f610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22842e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2591c650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25a42e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21ef2f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f94e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c9c6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25a72ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21c6b710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21e31f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2197a750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22d3ef50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21a18790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a228d2f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22db07d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21d0bdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22e28810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25b9bf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22957850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21e08210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2207f890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21b2bc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21b0b8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25bdec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25be0910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21acadd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a21a4d950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a228efc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fcf990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21c99d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21e939d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a219bed50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f2aa10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22f41d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21b55a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a228aedd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f6ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ac5e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2484aad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2494ee50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2547db10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21a9ce90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21c44b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21be9ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21d93b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a252cbf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25304fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249b0f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249efc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248b3f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a256a1c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25428fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a219e7c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21ce94d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21e5ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2201e510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256d4d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25294550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a252c9d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25589590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22bcad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22b795d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22b1cdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22acd610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a6ee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a1f650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a229c3e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20515690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20549e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2058b6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a205beed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c27710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c59f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22eaa750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22fb2f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22ff5790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23029f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a230c27d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a230f4fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23134810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2316af90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a231aa850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2322abd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23261890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232a0c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232d58d0>]],
#       dtype=object)

# %% [markdown]
# ### Analise de outlier por box-plot

# %%
exibirBoxplotPorVariavel(normed_data)

# %%
normed_data.to_csv('../Data/Processed/wine/normedBigTableWines.csv', sep=";", index=False)
