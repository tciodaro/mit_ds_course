# %% [markdown]
# # Projeto DIVINO
# ## Normalização por Min/Max

# %%
import pandas as pd
from ipynb.fs.full.data_analiser import *

# %% [markdown]
# #### Carregando dados

# %%
dados = pd.read_csv('../Data/Processed/wine/bigTableWines.csv', sep=";")
dadosNumericos = dados.drop('Tipo Vinho', axis=1)
variavelAlvo = 'quality'
dados.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality Tipo Vinho
# 0      9.4        5        Red
# 1      9.8        5        Red
# 2      9.8        5        Red
# 3      9.8        6        Red
# 4      9.4        5        Red

# %% [markdown]
# #### Normalizando

# %%
normed_data = normalizarPorMinMax(dadosNumericos)

# %% [markdown]
# #### KDE e Histograma comparando dados originais e normalizados

# %%
exibirHistogramaComKdeParaCadaVariavel2('Dados Originais', dadosNumericos, 'Min/Max', normed_data)

# %% [markdown]
# ### Faixa Dinâmica de Cada Variável:

# %%
exibirFaixaDinamicaDasVariaveis(normed_data)
# Out:
#                       Min  Max  Range
# fixed acidity         0.0  1.0    1.0
# volatile acidity      0.0  1.0    1.0
# citric acid           0.0  1.0    1.0
# residual sugar        0.0  1.0    1.0
# chlorides             0.0  1.0    1.0
# free sulfur dioxide   0.0  1.0    1.0
# total sulfur dioxide  0.0  1.0    1.0
# density               0.0  1.0    1.0
# pH                    0.0  1.0    1.0
# sulphates             0.0  1.0    1.0
# alcohol               0.0  1.0    1.0
# quality               0.0  1.0    1.0

# %% [markdown]
# ### Histograma e KDE das Variáveis

# %%
exibirHistogramaComKdeParaCadaVariavel(normed_data)

# %% [markdown]
# ### Histogramas e KDE para diferentes grupos.

# %%
exibirHistogramaComKdeParaCadaVariavelComAgrupamento(variavelAlvo, normed_data)

# %% [markdown]
# ### Coeficientes de Correlação

# %%
exibirGraficoCoeficientesDeCorrelacao(variavelAlvo, normed_data)

# %% [markdown]
# ### Scatter Matrix

# %%
exibirScatterMatrix(normed_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a258ed990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a258ed190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251a6610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ffa1110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2453ac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a250d6e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256a0750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243c80d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c0e490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ad7bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2453b290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24553e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24252a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b65090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25bfa950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ac1bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248aa110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d1e150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24dba3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a259a64d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251d6ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24fc9790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2455ff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a246c07d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24be72d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2439f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249fcf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e6c850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2502fbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ae6890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a247f7c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a252c18d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2498fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24f40910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2517ac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24dde950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24ac0cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2550e990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24731d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25c5f9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244e8d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24691a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d01490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d62a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2567edd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c93a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a247b3e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2492dad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2430be50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25751b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a255b8e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2525bb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25d22ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25d40b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25c74f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e38bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24601f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a242d7c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24459f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245b4c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24566fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a3fc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243374d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24859cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d59510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24d53a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120968550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12099cd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1209e8590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120a75d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120a2a5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120ab6dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x120b4f610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120af5e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120b91650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120c1ce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120bd3690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120c06e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256be6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a256f0ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25620710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120fdef10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121020750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121053f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x121096790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1210c8f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12110b7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12113dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121181810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1211b2f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1211f5850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23238bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2326f890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232acc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2440e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a244c8c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24641910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a246fec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24777950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24873cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248ec990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249aad10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a619d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a9fd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b57a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24bd4d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ccba50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e0bdd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24ec2a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24f7fe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ff6ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25134e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a251ebb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25269e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25361b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2539fed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a253d5b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25478f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a254afbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25540f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a25577c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2565bf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25720c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25909fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25940c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25ab54d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25aebcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25b6d510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25ba3d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25d9a550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25dd1d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25e12590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a25e47d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25e875d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25ebddd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25efd610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25f31e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25f70650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25fa7e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25fe6690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2601ce90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2605d6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26090ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a260d1710>]],
#       dtype=object)

# %% [markdown]
# ### Analise de outlier por box-plot

# %%
exibirBoxplotPorVariavel(normed_data)
