# %% [markdown]
# # Projeto DIVINO
# ## Normalização por Standard Scaler

# %%
import pandas as pd
from ipynb.fs.full.data_analiser import *

# %% [markdown]
# #### Carregando dados

# %%
dados = pd.read_csv('../Data/Processed/wine/bigTableWines.csv', sep=";")
dadosNumericos = dados.drop('Tipo Vinho', axis=1)
variavelAlvo = 'quality'
dados.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.59         0.14             1.9      0.076
# 1            7.8              0.59         0.14             2.6      0.086
# 2            7.8              0.59         0.14             2.3      0.086
# 3            8.8              0.28         0.49             1.9      0.075
# 4            7.4              0.59         0.14             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.42       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.42       0.56
#
#    alcohol  quality Tipo Vinho
# 0      9.4      5.0        Red
# 1      9.8      5.0        Red
# 2      9.8      5.0        Red
# 3      9.8      6.0        Red
# 4      9.4      5.0        Red

# %% [markdown]
# #### Normalizando

# %%
normed_data = normalizarPorStandardScaler(dadosNumericos)

# %% [markdown]
# #### KDE e Histograma comparando dados originais e normalizados

# %%
exibirHistogramaComKdeParaCadaVariavel2('Dados Originais', dadosNumericos, 'Std Scaling', normed_data)

# %% [markdown]
# ### Faixa Dinâmica de Cada Variável:

# %%
exibirFaixaDinamicaDasVariaveis(normed_data)
# Out:
#                        Min   Max  Range
# fixed acidity        -1.29  1.92   3.21
# volatile acidity     -1.15  1.99   3.14
# citric acid          -1.66  1.62   3.28
# residual sugar       -0.95  1.91   2.86
# chlorides            -1.19  1.87   3.06
# free sulfur dioxide  -1.41  1.65   3.06
# total sulfur dioxide -1.67  1.45   3.13
# density              -1.54  1.44   2.97
# pH                   -1.50  1.59   3.09
# sulphates            -1.37  1.79   3.17
# alcohol              -1.27  1.72   2.99
# quality              -1.13  1.60   2.74

# %% [markdown]
# ### Histograma e KDE das Variáveis

# %%
exibirHistogramaComKdeParaCadaVariavel(normed_data)

# %% [markdown]
# ### Histogramas e KDE para diferentes grupos.

# %%
exibirHistogramaComKdeParaCadaVariavelComAgrupamento(variavelAlvo, normed_data)

# %% [markdown]
# ### Coeficientes de Correlação

# %%
exibirGraficoCoeficientesDeCorrelacao(variavelAlvo, normed_data)

# %% [markdown]
# ### Scatter Matrix

# %%
exibirScatterMatrix(normed_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a23542510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236f0d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a230ada10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2376bd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23166a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23433c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2336edd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232c2590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232c24d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236bd7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23284cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a237abdd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24814b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23089210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22fb9790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22f7cc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a235cc590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a235bd610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a234581d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d80690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa5a6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d987d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236eadd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23547c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23031dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24655810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f218d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a242f3b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ef86d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24102350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2341e290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a238b8c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a238a1950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24caacd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23080990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ecdd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a231809d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2323bd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24af4a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23825d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a59a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d94dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23cbda90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b39e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249a6ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a246e3e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24749b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a6de90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a247ca790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248ceed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2456db90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24640f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2452df90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245bdf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a241e3c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a246adf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24707990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a241ccfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a241afc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2448c4d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2447fcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a233477d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2363ed10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23585550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a230f4d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2437b590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2426fd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243195d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243fbdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a231b8610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23406e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a242c2650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24425e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245ac690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a243bcad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a234e46d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a231f4ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24227710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24259f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2435d750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2461ff50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f98e790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f93bf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f8af7d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f858fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f815810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f7c0f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f77c850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f732bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f6e3890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f8d2c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f9098d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24c6dc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b41910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd0ec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd46950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11fd84cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fdbc990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fdf9d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fe329d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fe6fd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fea7a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fee4d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ff1ca50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ff59dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ff90a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ffcfe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fe6ad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22025e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23944b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23982e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a239b9b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a239f8ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a94b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ad2f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b09bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b9df50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23bd2c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c12f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c48c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23ceefd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d21c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23db54d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23debcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23e2b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23e60d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f07550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f3bd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23f7b590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24003d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a240435d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24079dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a240b9610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2478ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24863650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a248e2e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24923690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249afe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249f06d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a25ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ac0710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24b8bf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24bcc750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ceff50>]],
#       dtype=object)

# %% [markdown]
# ### Analise de outlier por box-plot

# %%
exibirBoxplotPorVariavel(normed_data)
