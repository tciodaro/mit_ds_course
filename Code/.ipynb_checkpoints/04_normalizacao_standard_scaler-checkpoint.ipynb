# %% [markdown]
# # Projeto DIVINO
# ## Normalização por Standard Scaler

# %%
import pandas as pd
from ipynb.fs.full.data_analiser import *

# %% [markdown]
# #### Carregando dados

# %%
dados = pd.read_csv('../Data/Processed/wine/bigTableWines.csv', sep=";")
dadosNumericos = dados.drop('Tipo Vinho', axis=1)
variavelAlvo = 'quality'
dados.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality Tipo Vinho
# 0      9.4        5        Red
# 1      9.8        5        Red
# 2      9.8        5        Red
# 3      9.8        6        Red
# 4      9.4        5        Red

# %% [markdown]
# #### Normalizando

# %%
normed_data = normalizarPorStandardScaler(dadosNumericos)

# %% [markdown]
# #### KDE e Histograma comparando dados originais e normalizados

# %%
exibirHistogramaComKdeParaCadaVariavel2('Dados Originais', dadosNumericos, 'Std Scaling', normed_data)

# %% [markdown]
# ### Faixa Dinâmica de Cada Variável:

# %%
exibirFaixaDinamicaDasVariaveis(normed_data)
# Out:
#                        Min    Max  Range
# fixed acidity        -2.63   6.70   9.33
# volatile acidity     -1.58   7.53   9.11
# citric acid          -2.19   9.23  11.42
# residual sugar       -1.02  12.69  13.70
# chlorides            -1.34  15.84  17.18
# free sulfur dioxide  -1.66  14.56  16.23
# total sulfur dioxide -1.94   5.74   7.68
# density              -2.53  14.77  17.30
# pH                   -3.10   4.92   8.02
# sulphates            -2.09   9.87  11.96
# alcohol              -2.09   3.70   5.79
# quality              -3.23   3.64   6.87

# %% [markdown]
# ### Histograma e KDE das Variáveis

# %%
exibirHistogramaComKdeParaCadaVariavel(normed_data)

# %% [markdown]
# ### Histogramas e KDE para diferentes grupos.

# %%
exibirHistogramaComKdeParaCadaVariavelComAgrupamento(variavelAlvo, normed_data)

# %% [markdown]
# ### Coeficientes de Correlação

# %%
exibirGraficoCoeficientesDeCorrelacao(variavelAlvo, normed_data)

# %% [markdown]
# ### Scatter Matrix

# %%
exibirScatterMatrix(normed_data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a21f8bb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f83f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23160210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a207ac790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2255ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21a16750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2306f650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fb2b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fb2c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a222ab790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22977790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a227f9250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a21e2af10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22995f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a223b4e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a218c7650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22870590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a225edf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21cfcfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21eeed90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a227e6590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a226ee310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a224b8f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22055750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a21d98f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22327790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22108f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21b9d7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22228fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21df9810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22869f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21c33850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a226a6bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22811890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2226bc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a226078d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22f33c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21e41910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a219cfc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2215c950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22556cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a227cf990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a223d3d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f209d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21cb8d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21b26a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22581d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21d1ca50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22ce2dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21ea4a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22b50e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22e62ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c07e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2332eb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232d4f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22733b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a233a2ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2332bb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2191bf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21a68bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a220a5f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21f40c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22396f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2249ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22463fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21c67c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21da74d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21ddbcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dfe3510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e023d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e0bb550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e065d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e0fc590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e18ad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e13e5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e1ccdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e265610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e20ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e5b0650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e5e3e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22c66690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e624e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e6666d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e69aed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e6db710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e70ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e752750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e783f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e7c8790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e7faf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e83b7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e871fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a208b4810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a208e8f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21992850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21a50bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a21b07890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21bc5c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21bfc8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21d3bc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21eb3910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21fefc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a220a8950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a220e5cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2219d990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2221bd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a223139d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22511d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a225c9a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22646d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2277ca50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22839dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a228b1a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a229ffe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a36ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22a77e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22aacb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22aece90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22b87b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22bc7ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22ca1b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22e88f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22ebcbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23034f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a230aac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a230ecf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23174c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a231b4fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a231eac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a233e34d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23418cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23458510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2348dd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a234cd550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23502d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23543590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23576d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a235b75d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a235ecdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2362d610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23662e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236a2650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a236d6e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23718690>]],
#       dtype=object)

# %% [markdown]
# ### Analise de outlier por box-plot

# %%
exibirBoxplotPorVariavel(normed_data)
