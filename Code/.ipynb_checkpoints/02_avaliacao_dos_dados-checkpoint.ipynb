# %% [markdown]
# # Projeto DIVINO
# ## Avaliação dos Dados

# %%
import pandas as pd
from ipynb.fs.full.data_analiser import *

data = pd.read_csv('../Data/Processed/wine/bigTableWines.csv', sep=";")

dadosNumericos = data.copy()
dadosNumericos.drop(['Tipo Vinho'], axis=1, inplace=True)
variavelAlvo = 'quality'

# %% [markdown]
# ### Verificação de dados faltantes

# %%
print('Verificação de dados faltantes')
describe(data)
# Out:
# Verificação de dados faltantes
# Total de linhas: 6497
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        6497.00           6497.00      6497.00         6497.00
# mean            7.22              0.34         0.32            5.44
# std             1.30              0.16         0.15            4.76
# min             3.80              0.08         0.00            0.60
# 25%             6.40              0.23         0.25            1.80
# 50%             7.00              0.29         0.31            3.00
# 75%             7.70              0.40         0.39            8.10
# max            15.90              1.58         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    6497.00              6497.00               6497.00  6497.00  6497.00
# mean        0.06                30.53                115.74     0.99     3.22
# std         0.04                17.75                 56.52     0.00     0.16
# min         0.01                 1.00                  6.00     0.99     2.72
# 25%         0.04                17.00                 77.00     0.99     3.11
# 50%         0.05                29.00                118.00     0.99     3.21
# 75%         0.06                41.00                156.00     1.00     3.32
# max         0.61               289.00                440.00     1.04     4.01
#
#        sulphates  alcohol  quality
# count    6497.00  6497.00  6497.00
# mean        0.53    10.49     5.82
# std         0.15     1.19     0.87
# min         0.22     8.00     3.00
# 25%         0.43     9.50     5.00
# 50%         0.51    10.30     6.00
# 75%         0.60    11.30     6.00
# max         2.00    14.90     9.00

# %%
quantificarDadosFaltantes(data)
# Out:
# fixed acidity           0.0
# volatile acidity        0.0
# citric acid             0.0
# residual sugar          0.0
# chlorides               0.0
# free sulfur dioxide     0.0
# total sulfur dioxide    0.0
# density                 0.0
# pH                      0.0
# sulphates               0.0
# alcohol                 0.0
# quality                 0.0
# Tipo Vinho              0.0
# dtype: float64

# %% [markdown]
# #### Análise:
# O count das variáveis é igual ao total de linhas, o que indica não haver dados faltantes. Isso é evidenciado pela equação abaixo que quantifica dados faltantes por variável:

# %% [markdown]
# ### Faixa Dinâmica de Cada Variável:

# %%
exibirFaixaDinamicaDasVariaveis(dadosNumericos)
# Out:
#                        Min     Max   Range
# fixed acidity         3.80   15.90   12.10
# volatile acidity      0.08    1.58    1.50
# citric acid           0.00    1.66    1.66
# residual sugar        0.60   65.80   65.20
# chlorides             0.01    0.61    0.60
# free sulfur dioxide   1.00  289.00  288.00
# total sulfur dioxide  6.00  440.00  434.00
# density               0.99    1.04    0.05
# pH                    2.72    4.01    1.29
# sulphates             0.22    2.00    1.78
# alcohol               8.00   14.90    6.90
# quality               3.00    9.00    6.00

# %% [markdown]
# #### Análise:
# Observa-se que as variáveis "free sulfur dioxide" e "total sulfur dioxide" tem as maiores faixas, sendo a primeira o caso mais preocupante. Ao longo da análise vamos observar se trata-se de efeito de outlier ou tem a ver com a própria distribuição dos dados, quando podemos decidir por aplicar um log, por exemplo.

# %% [markdown]
# ### Histograma e KDE

# %%
exibirHistogramaComKdeParaCadaVariavel(dadosNumericos)

# %% [markdown]
# ### Análise:
# O KDE e o histograma mostraram que algumas variáveis com faixa dinâmica pequena possuem uma calda longa, tais como "citric acid", "residual sugar" e "chlorides".

# %% [markdown]
# ### Histogramas e KDE para diferentes grupos.

# %%
exibirHistogramaComKdeParaCadaVariavelComAgrupamento(variavelAlvo, dadosNumericos)

# %% [markdown]
# ### Análise:
# Exceto pela variável "alcohol", todas as demais possuem uma distribuição que se confunde quando feito o agrupamento e parecem não fornecer informações relevantes. A variável "density" parece poder fornecer informação mais relevante se ajustarmos a faixa dinâmica.

# %% [markdown]
# ### Coeficientes de Correlação

# %%
exibirGraficoCoeficientesDeCorrelacao(variavelAlvo, data)

# %% [markdown]
# #### Análise:
# As variáveis abaixo são as que possuem maior correlação com a variável alvo:
# * volatile acidity
# * density
# * alcohol

# %% [markdown]
# ### Scatter Matrix

# %%
exibirScatterMatrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a28064c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27ef55d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27f24dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28348610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28378e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a283b4650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a283de290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28423690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2842d210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28461b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a284cced0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2850e710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a28540f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28582750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a285b6f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a285f8790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2862cf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2866e7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a286a1fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a286e4810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28717f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2875a850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28785490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a287cf890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a287fa4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a288438d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2886e510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a288b8910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a288e3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2892d950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2895a590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a289a5990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a289d15d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28a1a9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28a44610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28a8fa10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a28ab9650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28b03a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28b2e690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28b78a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28ba46d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28bf0ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28c19710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28c64b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28c8f750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28cd7b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28d05790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28d4eb90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a276c60d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a277f1cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27df12d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27eec110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27993ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27cf3490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27ddc950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27a1ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27624bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a276d7a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2730b190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2635a6d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2725e990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26858b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26c7c250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26296050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25ac64d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27332810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a261fef90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a279c0850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26b9b490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27936890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2763a4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27b0f8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27714510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27a3d910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26abc550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26c76b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a279081d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27aa0990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2788a5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a266a89d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2693c610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a275fea10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26359650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a264eda50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a26764690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2715b790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a271676d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2627bad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26253710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26412b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a265f2750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26848b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26a74790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26ec9b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26501a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27019bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a274baf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2779ac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a265adf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26b1bc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26db9fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a274e0c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a278114d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a277bfcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2782c510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2681fd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a275a5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27672d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27986590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2630fd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a264685d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2679ddd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a278bd610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a266c5e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a268d8650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26a10e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27543690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a263cae90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2671d6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26679750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2775b710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a277354d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a262bf750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a262f1f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26575790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a269a6f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a269697d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2639dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2649f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26611f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a267d5850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2687f490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a26ac8890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a26af54d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2759b8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27dad510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27d65910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27cc2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1228ff950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12292e590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1229b3990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1229df5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122a289d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122a53610>]],
#       dtype=object)

# %% [markdown]
# #### Análise:
# Meu sonho é entender esse gráfico. Mas me parece que não há nenhum caso de correlação linear entre as variáveis que pudesse justificar a retirada de alguma delas.

# %% [markdown]
# ### Analise de outlier por box-plot

# %%
exibirBoxplotPorVariavel(dadosNumericos)

# %% [markdown]
# #### Análise:
# Há outiliers em:
# * citric acid
# * residual sugar
# * chlorides
# * free sulfur dioxide
