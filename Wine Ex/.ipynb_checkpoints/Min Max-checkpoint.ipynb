# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_red = pd.read_csv('../Data/Raw/wine/winequality-red.csv', sep=';')
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df_white = pd.read_csv('../Data/Raw/wine/winequality-white.csv', sep=';')
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
df_red['red'] = 1
df_white['red'] = 0

# %%
df_total = pd.concat([df_white,df_red])
df_total = df_total.reset_index()
df_total = df_total.drop(columns = 'index')

# %% [markdown]
# Normalizing Data

# %%
df_total.describe()['fixed acidity']['mean']
# Out:
# 7.2153070647991235

# %%
df_total.describe()['fixed acidity']['std']
# Out:
# 1.296433757799818

# %%
norm_col = df_total.columns[:len(df_total.columns)-2]
df_norm = df_total
norm_col
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
#for cname in df_norm.columns[:len(df_norm.columns)-2]:    
    #for i in range(df_total[cname].count()):
        #df_norm[cname][i] = math.log(df_norm[cname][i])

# %%
df_norm[(df_norm['citric acid']==0)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 115             5.5             0.485          0.0             1.5      0.065
# 300             6.1             0.410          0.0             1.6      0.063
# 302             6.1             0.410          0.0             1.6      0.063
# 780             6.0             0.395          0.0             1.4      0.042
# 862             4.8             0.340          0.0             6.5      0.028
# ...             ...               ...          ...             ...        ...
# 6353            6.5             0.900          0.0             1.6      0.052
# 6359            6.2             0.785          0.0             2.1      0.060
# 6448            7.1             0.680          0.0             2.3      0.087
# 6449            7.1             0.670          0.0             2.3      0.083
# 6451            7.3             0.735          0.0             2.2      0.080
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 115                   8.0                 103.0  0.99400  3.63       0.40
# 300                  36.0                  87.0  0.99140  3.27       0.67
# 302                  36.0                  87.0  0.99140  3.27       0.67
# 780                   7.0                  55.0  0.99135  3.37       0.38
# 862                  33.0                 163.0  0.99390  3.36       0.61
# ...                   ...                   ...      ...   ...        ...
# 6353                  9.0                  17.0  0.99467  3.50       0.63
# 6359                  6.0                  13.0  0.99664  3.59       0.61
# 6448                 17.0                  26.0  0.99783  3.45       0.53
# 6449                 18.0                  27.0  0.99768  3.44       0.54
# 6451                 18.0                  28.0  0.99765  3.41       0.60
#
#       alcohol  quality  red
# 115       9.7        4    0
# 300      10.8        6    0
# 302      10.8        6    0
# 780      11.2        4    0
# 862       9.9        6    0
# ...       ...      ...  ...
# 6353     10.9        6    1
# 6359     10.0        4    1
# 6448      9.5        5    1
# 6449      9.4        5    1
# 6451      9.4        5    1
#
# [151 rows x 13 columns]

# %%
#remove 0 from citric acid
df_norm.loc[(df_norm['citric acid'] == 0),'citric acid'] = 0.05
df_norm[(df_norm['citric acid']==0)]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, red]
# Index: []

# %%
for cname in df_norm.columns[:len(df_norm.columns)-2]:
    
    #df_norm[cname] = np.log(df_total[cname]) #pq df total tambem recebe o log?
    df_norm[cname] = np.log(df_norm[cname])

# %%
df_norm
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0
# ...         ...       ...      ...  ...
# 6492  -0.544727  2.351375        5    1
# 6493  -0.274437  2.415914        6    1
# 6494  -0.287682  2.397895        6    1
# 6495  -0.342490  2.322388        5    1
# 6496  -0.415515  2.397895        6    1
#
# [6497 rows x 13 columns]

# %% [markdown]
# PLOTTING

# %%
faixa_dinamica = pd.concat([df_norm.min(),df_norm.max()],axis =1)
faixa_dinamica.columns = ['Min','Max']
faixa_dinamica['Range'] =faixa_dinamica['Max'] - faixa_dinamica['Min']
faixa_dinamica
# Out:
#                            Min       Max     Range
# fixed acidity         1.335001  2.766319  1.431318
# volatile acidity     -2.525729  0.457425  2.983153
# citric acid          -4.605170  0.506818  5.111988
# residual sugar       -0.510826  4.186620  4.697445
# chlorides            -4.710531 -0.492658  4.217872
# free sulfur dioxide   0.000000  5.666427  5.666427
# total sulfur dioxide  1.791759  6.086775  4.295015
# density              -0.012974  0.038239  0.051213
# pH                    1.000632  1.388791  0.388159
# sulphates            -1.514128  0.693147  2.207275
# alcohol               2.079442  2.701361  0.621920
# quality               3.000000  9.000000  6.000000
# red                   0.000000  1.000000  1.000000

# %%
df_norm[(df_norm['citric acid']==0)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 946        2.104134         -1.064211          0.0        2.901422  -3.057608
# 1722       2.014903         -0.916291          0.0        2.970414  -3.194183
# 1775       2.041220         -0.713350          0.0        2.975530  -3.506558
# 3043       1.974081         -1.560648          0.0        0.095310  -1.870803
# 3497       2.041220         -0.843970          0.0        2.993229  -3.442019
# 5049       2.219203         -0.653926          0.0        1.223775  -0.494296
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 946              4.007333              5.323010 -0.000350  1.085189
# 1722             3.496508              4.997212 -0.002303  1.175573
# 1775             3.332205              4.905275 -0.002704  1.175573
# 3043             3.828641              4.736198 -0.006924  1.081805
# 3497             3.737670              5.099866 -0.002583  1.190888
# 5049             3.465736              4.234107 -0.000400  1.007958
#
#       sulphates   alcohol  quality  red
# 946   -0.843970  2.261763        5    0
# 1722  -0.967584  2.484907        6    0
# 1775  -0.916291  2.484907        6    0
# 3043  -0.843970  2.219203        6    0
# 3497  -0.693147  2.484907        6    0
# 5049   0.693147  2.240710        4    1

# %%
df_norm.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7CC78948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D3951C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D3C7D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D3FFB08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D439888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D46E608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D4A3388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D4D9108>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D4E3108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D50FEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D578D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D5B1E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D5E9FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D622088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D65C248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F7D694408>]],
#       dtype=object)

# %%
df_norm.plot.kde()

# %%
for cname in df_norm.columns:
    plt.figure()
    df_norm[cname].plot.kde()
    plt.title(cname)

# %%
for cname in df_norm.columns:
    plt.figure()
    df_norm[cname].hist()
    plt.title(cname)

# %%
for cname in df_norm.columns[:len(df_norm.columns)-2]:
    plt.figure()
    df_norm.groupby('quality')[cname].plot.kde(legend = True)
    plt.title(cname)

# %%
df_norm.corr()['quality'].drop('quality').plot.bar()

# %%
sns.boxplot(df_norm)

# %%
sns.pairplot(df_norm)
